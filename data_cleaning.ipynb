# %%
import pandas as pd

# %%
overweight = pd.read_excel('data/overweight.xlsx', sheet_name='Trend', header=8).iloc[:,:23]
stunting = pd.read_excel('data/stunting.xlsx', sheet_name='Trend', header=8).iloc[:,:23]
wasting = pd.read_excel('data/wasting.xlsx', sheet_name='Trend', header=8).iloc[:,:23]

# %%
wasting
# Out:
#       UNICEF_Survey_ID ISO3Code  CountryName UNICEF_Reporting_Sub_Region  \
# 0                    1      AFG  Afghanistan                          SA
# 1                    2      AFG  Afghanistan                          SA
# 2                    3      AFG  Afghanistan                          SA
# 3                 3076      AFG  Afghanistan                          SA
# 4                    6      ALB      Albania                        EECA
# ...                ...      ...          ...                         ...
# 1050               789      ZWE     Zimbabwe                         ESA
# 1051               790      ZWE     Zimbabwe                         ESA
# 1052               791      ZWE     Zimbabwe                         ESA
# 1053               822      ZWE     Zimbabwe                         ESA
# 1054              2445      ZWE     Zimbabwe                         ESA
#
#      UNRegion WHORegion            WB_Latest DataSourceYears  CMRS_year  \
# 0        Asia      EMRO           Low Income            1997       1997
# 1        Asia      EMRO           Low Income            2004       2004
# 2        Asia      EMRO           Low Income            2013       2013
# 3        Asia      EMRO           Low Income            2018       2018
# 4      Europe      EURO  Upper Middle Income            2005       2005
# ...       ...       ...                  ...             ...        ...
# 1050   Africa      AFRO  Lower Middle Income            2009       2009
# 1051   Africa      AFRO  Lower Middle Income         2010-11       2010
# 1052   Africa      AFRO  Lower Middle Income            2014       2014
# 1053   Africa      AFRO  Lower Middle Income            2015       2015
# 1054   Africa      AFRO  Lower Middle Income            2019       2019
#
#      DataSourceTypeGlobal  ... National_r National_ll National_ul  \
# 0                    MICS  ...       17.3         NaN         NaN
# 1                     NNS  ...        9.1         NaN         NaN
# 2                     NNS  ...        9.5         8.7        10.4
# 3                   Other  ...        5.1         4.7         5.6
# 4                    MICS  ...        7.3         5.6         9.5
# ...                   ...  ...        ...         ...         ...
# 1050                 MICS  ...        2.4         2.0         2.9
# 1051                  DHS  ...        3.2         2.7         3.7
# 1052                 MICS  ...        3.2         2.9         3.6
# 1053                  DHS  ...        3.3         2.8         3.9
# 1054                 MICS  ...        2.9         2.4         3.5
#
#       National_weighted_N  National_Footnote  male_r  male_ll male_ul  \
# 0                     NaN                  b     NaN      NaN     NaN
# 1                     NaN                  b     NaN      NaN     NaN
# 2            4.247295e+06                 rs    10.3      9.4    11.4
# 3            1.969242e+04                 rs     6.1      5.4     6.8
# 4            1.075335e+03                        7.3      5.0    10.5
# ...                   ...                ...     ...      ...     ...
# 1050         6.210139e+03                  s     2.9      2.4     3.6
# 1051         5.365511e+03                        3.7      3.0     4.6
# 1052         9.549843e+03                  s     3.7      3.1     4.3
# 1053         6.266194e+03                        3.3      2.6     4.2
# 1054         5.968469e+03                        3.0      2.4     3.7
#
#       male_weighted_N  male_Footnote
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2        2.167205e+06             rs
# 3        1.009931e+04             rs
# 4        5.864434e+02
# ...               ...            ...
# 1050     3.114507e+03              s
# 1051     2.663538e+03
# 1052     4.747748e+03              s
# 1053     3.103694e+03
# 1054     2.959811e+03
#
# [1055 rows x 23 columns]
